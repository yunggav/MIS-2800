# %% [markdown]
# <a href="https://colab.research.google.com/github/yunggav/MIS-2800/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for SQLite3 to work using SQLite Magic
# !pip install ipython-sql prettytable==3.10 pandas==2.2.2

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///AdCampaigns2026.db

# %%
#Block 1
# Instructions: There is a typo in the table.  Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer - I corrected this by adding TABLE, it just said CREATE.

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 100000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %% [markdown]
# 2. How did you fix the error in Block #2? Answer - I added INSERT as well as marketing_brands.

# %%
#Block 3
# -- Instructions: Fix the code to select all the columns
# from the Marketing_Brands table
# %%sql
SELECT * FROM Marketing_Brands
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %% [markdown]
# 3. How did you fix the error in Block #3? Answer - It was missing * to select all columns

# %%
#Block 4
# -- Instructions: Fix the code to display only the brand names and
# brand types that had budget over 700000
# %%sql
SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %% [markdown]
# 4. How did you fix the error in Block #4? Answer - Pretyytable==3.10 had a period after it which was removed. Pandas==2.2.2 was installed and in the print statement I added a closing parenthesis. The CREATE Marketing_brands was missing the word TABLE. I added the word INTO as it was only INSERT for statement syntax error. The SELECT statement was missing the * to select columns which was added. Finally I needed to specify brand_name and brand_type after SELECT, I then needed to add the WHERE statement to filter.

# %%
#Block 5
# Instructions: Fix the code to find the brand types that are Religious
# %%sql
SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious'
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %% [markdown]
# 5. How did you fix the error in Block #5? Answer - I added the brand_type after the select statement. I also added the Where clause to filter

# %%
#Block 6
# -- Instructions: Fix the code to display the
# brand names that have a budget under 1000000
# %%sql
SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %% [markdown]
# 6. How did you fix the error in Block #6? Answer - I added the brand_name after SELECT statement. I also added the WHERE clause to filter.

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in
# Colab without having to wrap in Python. Hint: It's Magic!
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %% [markdown]
# 7. How did you fix the error in Block #7? Answer - I needed to add the %%sql function

# %%
#Block 8
# Instructions: Find the brands where the brand type is
# Snacks or Beverages. Display only the brand names.
# %%sql
SELECT brand_name FROM Marketing_Brands WHERE brand_type IN ('Snacks', 'Beverages');
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %% [markdown]
# 8. How did you fix the error in Block #8? Answer - The columns were selected but had no filtering, i corrected it by adding the filter to brand_name and type , and Snacks/Beverages added. The magic command was also placed incorrectly which was fixed.

# %%
#Block 9
# Instructions: Sort the table by brand budget in
# DESC order. Display only the brand_name and brand_budget.
# %%sql
SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %% [markdown]
# 9. How did you fix the error in Block #9? Answer - The sql magic command needed to be in its own line. I also needed to add spefics for the SELECT statement like the brand name and budget

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql
SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 10. How did you fix the error in Block #10? Answer - I added the sql magic command as well as the SQL query - SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
